# %%
import pandas as pd
import numpy as np 
from sklearn import linear_model

# %%
df= pd.read_csv('MFG10YearTerminationData.csv', usecols= [0,5,6,10], index_col=None )

# %%
df
# Out:
#        EmployeeID  age  length_of_service  store_name
# 0            1318   52                 17          35
# 1            1318   53                 18          35
# 2            1318   54                 19          35
# 3            1318   55                 20          35
# 4            1318   56                 21          35
# ...           ...  ...                ...         ...
# 49648        8258   21                  2          34
# 49649        8264   19                  0          44
# 49650        8279   21                  2          39
# 49651        8296   19                  0          16
# 49652        8321   20                  1          13
#
# [49653 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# EmployeeID           0
# age                  0
# length_of_service    0
# store_name           0
# dtype: int64

# %%
df.length_of_service.iloc[5] = None

# %%
df.length_of_service.isnull().sum()
# Out:
# 1

# %%
median_value =df.length_of_service.median()

# %%
median_value
# Out:
# 10.0

# %%
df.length_of_service.fillna(median_value, inplace= True)

# %%
df.length_of_service.isnull().sum()
# Out:
# 0

# %%
df
# Out:
#        EmployeeID  age  length_of_service  store_name
# 0            1318   52               17.0          35
# 1            1318   53               18.0          35
# 2            1318   54               19.0          35
# 3            1318   55               20.0          35
# 4            1318   56               21.0          35
# ...           ...  ...                ...         ...
# 49648        8258   21                2.0          34
# 49649        8264   19                0.0          44
# 49650        8279   21                2.0          39
# 49651        8296   19                0.0          16
# 49652        8321   20                1.0          13
#
# [49653 rows x 4 columns]

# %%
data = df[: 41]

# %%
data
# Out:
#     EmployeeID  age  length_of_service  store_name
# 0         1318   52               17.0          35
# 1         1318   53               18.0          35
# 2         1318   54               19.0          35
# 3         1318   55               20.0          35
# 4         1318   56               21.0          35
# 5         1318   57               10.0          35
# 6         1318   58               23.0          35
# 7         1318   59               24.0          35
# 8         1318   60               25.0          35
# 9         1318   61               26.0          35
# 10        1319   49               17.0          35
# 11        1319   50               18.0          35
# 12        1319   51               19.0          35
# 13        1319   52               20.0          35
# 14        1319   53               21.0          35
# 15        1319   54               22.0          35
# 16        1319   55               23.0          35
# ...

# %%
linear = linear_model.LinearRegression()

# %%
# df.department_name.astype('int')

# %%
linear.fit(df[['EmployeeID','age','length_of_service']], df.store_name)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([-0.0005426 , -0.14270163,  0.13914439])

# %%
linear.intercept_
# Out:
# 34.48696411188755

# %%
linear.predict([[1325,45,15]])
# Out:
# C:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([29.43360723])

# %%
# for i in df.age:
#     if i >=40:
#         print(df['age'])

# %%
# the caluations 
x=(-0.0005426*1325 + -0.14270163 *45 + 0.13914439* 15 ) + 34.48696411188755

# %%
x
# Out:
# 29.433611611887553

# %%
# linear.predict([[1325,45,15]]) and x is similar

# %% [markdown]
# ## Excercise using HR data

# %%
data = pd.read_csv('hiring.csv')

# %%
data
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
data.rename(columns= { 'test_score(out of 10)' : 'testscore',
                      'interview_score(out of 10)' : 'interview_score' ,
                      'salary($)' : 'salary' }, inplace= True)

# %%
missing = data.testscore.median()

# %%
data.testscore.fillna(missing, inplace=True)

# %%
data
# Out:
#   experience  testscore  interview_score  salary
# 0        NaN        8.0                9   50000
# 1        NaN        8.0                6   45000
# 2       five        6.0                7   60000
# 3        two       10.0               10   65000
# 4      seven        9.0                6   70000
# 5      three        7.0               10   62000
# 6        ten        8.0                7   72000
# 7     eleven        7.0                8   80000

# %%
# def replace_values(x):
#     if x=='NaN':
#         x=0
#         return x

# %%
data.experience.fillna('zero', inplace= True)

# %%
data
# Out:
#   experience  testscore  interview_score  salary
# 0       zero        8.0                9   50000
# 1       zero        8.0                6   45000
# 2       five        6.0                7   60000
# 3        two       10.0               10   65000
# 4      seven        9.0                6   70000
# 5      three        7.0               10   62000
# 6        ten        8.0                7   72000
# 7     eleven        7.0                8   80000

# %%
# pip install word2num
# Out:
# ...
#    ---------------------------------------- 0.0/98.4 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/98.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 98.4/98.4 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.7 MB 3.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.2/1.7 MB 2.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/1.7 MB 2.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 2.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.7 MB 2.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.7 MB 2.2 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.7 MB 2.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 2.2 MB/s eta 0:00:01
# ...

# %%
# pip install word2number
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5589 sha256=40393fe59f2406c638d855654be2b490cef1ae12f77ee6208391c0435ab98b3a
#   Stored in directory: c:\users\vishn\appdata\local\pip\cache\wheels\cd\ef\ae\073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from word2number import w2n

# %%
data
# Out:
#   experience  testscore  interview_score  salary
# 0       zero        8.0                9   50000
# 1       zero        8.0                6   45000
# 2       five        6.0                7   60000
# 3        two       10.0               10   65000
# 4      seven        9.0                6   70000
# 5      three        7.0               10   62000
# 6        ten        8.0                7   72000
# 7     eleven        7.0                8   80000

# %%
data['Experience'] = w2n.word_to_num(data['experience'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 data['Experience'] = w2n.word_to_num(data['experience'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\word2number\w2n.py:134, in word_to_num(number_sentence)
#     132 def word_to_num(number_sentence):
#     133     if type(number_sentence) is not str:
# --> 134         raise ValueError("Type of input is not string! Please enter a valid number word (eg. \'two million twenty three thousand and forty nine\')")
#     136     number_sentence = number_sentence.replace('-', ' ')
#     137     number_sentence = number_sentence.lower()  # converting input to lowercase
#
# ValueError: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')

# %%
data['experience'] = data.experience.apply(w2n.word_to_num,)

# %%
data
# Out:
#    experience  testscore  interview_score  salary
# 0           0        8.0                9   50000
# 1           0        8.0                6   45000
# 2           5        6.0                7   60000
# 3           2       10.0               10   65000
# 4           7        9.0                6   70000
# 5           3        7.0               10   62000
# 6          10        8.0                7   72000
# 7          11        7.0                8   80000

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()

# %%
reg.fit(data[['experience', 'testscore', 'interview_score']], data.salary)
# Out:
# LinearRegression()

# %% [markdown]
# ### Here we use the exitsing value to test the accuracy of the model
#
# [https://machinelearningmastery.com/regression-metrics-for-machine-learning/]
#
# ### Used two metrics
# 1. mean_absoule_error
# 2. mean_squared_error

# %%
reg.predict([[5,6,7]])
# Out:
# C:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([58312.95487627])

# %%
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
y_test= [[60000]]
y_pred = [[58312.95487627]]
mae= mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred,squared=False)
mse

# accu =accuracy_score(y_test, y_pred)
# Out:
# C:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 1687.0451237300003

# %%
mae
# Out:
# 1687.0451237300003

# %% [markdown]
# ## The error is less and satisfactory to the model so we can proceed furthur, there are no model with 0 errors, if exits its a trivial....

# %% [markdown]
# ### Trying out for the values

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53205.96797671])

# %%
reg.predict([[12,10,10]])
# Out:
# C:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])
